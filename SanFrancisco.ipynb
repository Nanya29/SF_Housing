# %%
#import Libraries
import pandas as pd
import hvplot.pandas
from pathlib import Path
import os
import geoviews as gv
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# checking current directory 
current_directory = os.getcwd()
print ("current Directory:", current_directory)
# Out:
# current Directory: C:\Users\princ\Desktop

# %%
#create path
data_0= Path("Resources/sfo_neighborhoods_census_data.csv")
data_1= Path("Resources/neighborhoods_coordinates.csv")
data_2= Path("Resources/housing_per_year.csv")

# %%
# read and diplay data 
sfo_data_df = pd.read_csv(data_0)
neighborhood_df = pd.read_csv(data_1)
yearly_housing = pd.read_csv(data_2)
sfo_data_df.head()
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945         372560        1239
# 1  2010        Anza Vista           267.932583         372560        1239
# 2  2010           Bayview           170.098665         372560        1239
# 3  2010  Buena Vista Park           347.394919         372560        1239
# 4  2010  Central Richmond           319.027623         372560        1239

# %%
# Rename "neighborhood" columnfrom sfo_data using "column"
columns= ["year", "Neighborhood", "sale_price_sqr_foot", "housing_units", "gross_rent"]
sfo_data_df.columns= columns
sfo_data_df.head()
# Out:
#    year      Neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945         372560        1239
# 1  2010        Anza Vista           267.932583         372560        1239
# 2  2010           Bayview           170.098665         372560        1239
# 3  2010  Buena Vista Park           347.394919         372560        1239
# 4  2010  Central Richmond           319.027623         372560        1239

# %% [markdown]
# # Calculate and Plot the Housing Units per Year

# %% [markdown]
# Step 1: Use the `groupby` function to group the data by year. Aggregate the results by the `mean` of the groups.

# %%
# Create a numerical aggregation that groups the data by the year and then averages the results.
# Select numerical columns 
num_columns= sfo_data_df.loc[:,["year", "sale_price_sqr_foot","housing_units", "gross_rent"]]

# Group data by year and aggregate results
yearly_housing_df = num_columns.groupby("year").mean()

# Review the DataFrame
yearly_housing_df
# Out:
#       sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010           369.344353       372560.0      1239.0
# 2011           341.903429       374507.0      1530.0
# 2012           399.389968       376454.0      2324.0
# 2013           483.600304       378401.0      2971.0
# 2014           556.277273       380348.0      3528.0
# 2015           632.540352       382295.0      3739.0
# 2016           697.643709       384242.0      4390.0

# %% [markdown]
# Step 2: Use the `hvplot` function to plot the `yearly_housing_df` DataFrame as a bar chart. Make the x-axis represent the `year` and the y-axis represent the `housing_units`.

# %%
# plot the housing units per year usind "hvplot"
yearly_housing_df.hvplot.bar(x='year', y='housing_units', title='Housing Units by Year', ylabel='Housing Units')
# Out:
# :Bars   [year]   (housing_units)

# %% [markdown]
# Step 3: Style and format the line plot to ensure a professionally styled visualization.

# %%
# Create a visual aggregation explore the housing units by year

# set min and max limits for Y-axis
max_lim= 365000
min_lim= 385000

yearly_housing_df.hvplot.bar(
    x='year',
    y='housing_units', 
    title='Housing Units by Year', 
    ylabel='Housing Units',
    ylim=(max_lim, min_lim), 
    width=900,
).opts(yformatter='%.0f')
# Out:
# :Bars   [year]   (housing_units)

# %% [markdown]
# **Question:** What is the overall trend in housing_units over the period being analyzed?
#
# **Answer:** There is an increase in housing units every year from the year 2010 to 2016.

# %% [markdown]
# ----

# %% [markdown]
# # Calculate and Plot the Average Sale Prices per Square Foot

# %% [markdown]
# ### Step 1: Group the data by year, and then average the results.

# %%
# Review the dataFrame
yearly_housing_df
# Out:
#       sale_price_sqr_foot  housing_units  gross_rent
# year
# 2010           369.344353       372560.0      1239.0
# 2011           341.903429       374507.0      1530.0
# 2012           399.389968       376454.0      2324.0
# 2013           483.600304       378401.0      2971.0
# 2014           556.277273       380348.0      3528.0
# 2015           632.540352       382295.0      3739.0
# 2016           697.643709       384242.0      4390.0

# %% [markdown]
# **Question:** What is the lowest gross rent reported for the years included in the DataFrame?
#
# **Answer:** The lowest gross rent was reported for the year 2010

# %% [markdown]
# ### Step 2: Create a new DataFrame named `prices_square_foot_by_year` by filtering out the “housing_units” column. The new DataFrame should include the averages per year for only the sale price per square foot and the gross rent.

# %%
# Filter out the housing_units column, creating a new DataFrame 
# Keep only sale_price_sqr_foot and gross_rent averages per year
prices_square_foot_by_year = yearly_housing_df.loc[:,["sale_price_sqr_foot", "gross_rent"]]

# Review the DataFrame
prices_square_foot_by_year
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353      1239.0
# 2011           341.903429      1530.0
# 2012           399.389968      2324.0
# 2013           483.600304      2971.0
# 2014           556.277273      3528.0
# 2015           632.540352      3739.0
# 2016           697.643709      4390.0

# %% [markdown]
# ### Step 3: Use hvPlot to plot the `prices_square_foot_by_year` DataFrame as a line plot.

# %% [markdown]
# ### Step 4: Style and format the line plot to ensure a professionally styled visualization.

# %%
# create a line plot for the prices of sqr foot per year

prices_square_foot_by_year.hvplot.line(
    x= "year",
    y=["sale_price_sqr_foot", "gross_rent"],
    ylabel= "Gross Rent/Sale Price Per Square Foot", 
    title="Sale Price per Square Foot and Average Gross Rent -2010-2016- San Farncisco", 
    width= 900
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %% [markdown]
# **Question:** Did any year experience a drop in the average sale price per square foot compared to the previous year?
#
# **Answer:** The graph shows a tiny drop in the year 2011.

# %% [markdown]
# **Question:** If so, did the gross rent increase or decrease during that year?
#
# **Answer:** There was a decrease.

# %% [markdown]
# ---

# %% [markdown]
# ### Step 1: Create a new DataFrame that groups the original DataFrame by year and neighborhood. Aggregate the results by the `mean` of the groups.

# %%
# Group by year and neighborhood and then create a new dataframe of the mean values
prices_by_year_by_neighborhood = sfo_data_df.groupby(["year","Neighborhood"]).mean()

# Review the DataFrame
prices_by_year_by_neighborhood
# Out:
#                              sale_price_sqr_foot  housing_units  gross_rent
# year Neighborhood
# 2010 Alamo Square                     291.182945       372560.0      1239.0
#      Anza Vista                       267.932583       372560.0      1239.0
#      Bayview                          170.098665       372560.0      1239.0
#      Buena Vista Park                 347.394919       372560.0      1239.0
#      Central Richmond                 319.027623       372560.0      1239.0
# ...                                          ...            ...         ...
# 2016 Telegraph Hill                   903.049771       384242.0      4390.0
#      Twin Peaks                       970.085470       384242.0      4390.0
#      Van Ness/ Civic Center           552.602567       384242.0      4390.0
#      Visitacion Valley                328.319007       384242.0      4390.0
#      Westwood Park                    631.195426       384242.0      4390.0
#
# [397 rows x 3 columns]

# %% [markdown]
# ### Step 2: Filter out the “housing_units” column to create a DataFrame that includes only the `sale_price_sqr_foot` and `gross_rent` averages per year.

# %%
# Filter out the housing_units
Yearly_neighborhood_prices = prices_by_year_by_neighborhood.loc[:, ["sale_price_sqr_foot", "gross_rent"]]

# Review the first and last five rows of the DataFrame
display(prices_by_year_by_neighborhood.head())
display(prices_by_year_by_neighborhood.tail())
# Out:
#                        sale_price_sqr_foot  housing_units  gross_rent
# year Neighborhood
# 2010 Alamo Square               291.182945       372560.0      1239.0
#      Anza Vista                 267.932583       372560.0      1239.0
#      Bayview                    170.098665       372560.0      1239.0
#      Buena Vista Park           347.394919       372560.0      1239.0
#      Central Richmond           319.027623       372560.0      1239.0
#                              sale_price_sqr_foot  housing_units  gross_rent
# year Neighborhood
# 2016 Telegraph Hill                   903.049771       384242.0      4390.0
#      Twin Peaks                       970.085470       384242.0      4390.0
#      Van Ness/ Civic Center           552.602567       384242.0      4390.0
#      Visitacion Valley                328.319007       384242.0      4390.0
#      Westwood Park                    631.195426       384242.0      4390.0

# %% [markdown]
# ### Step 3: Create an interactive line plot with hvPlot that visualizes both `sale_price_sqr_foot` and `gross_rent`. Set the x-axis parameter to the year (`x="year"`). Use the `groupby` parameter to create an interactive widget for `neighborhood`.
#
# ### Step 4: Style and format the line plot to ensure a professionally styled visualization.

# %%
# Use hvplot to create an interactive line plot of the average price per square foot
# The plot should have a dropdown selector for the neighborhood
Yearly_neighborhood_prices.hvplot.line( 
    x='year',
    y=['sale_price_sqr_foot', 'gross_rent'], 
    groupby="Neighborhood",
    xlabel='Year', 
    ylabel='Gross Rent/Sale Price Per Square Foot', 
    title='Sale Price Per Square Foot and Average Gross Rent -2010-2016- by Neighborhood',
    width= 800,
).opts(
    xformatter='%.0f')
# Out:
# :DynamicMap   [Neighborhood]
#    :NdOverlay   [Variable]
#       :Curve   [year]   (value)

# %% [markdown]
# **Question:** For the Anza Vista neighborhood, is the average sale price per square foot for 2016 more or less than the price that’s listed for 2012?
#
# **Answer:** Yes,it is

# %% [markdown]
# ## Build an Interactive Neighborhood Map

# %% [markdown]
# ### Step 1: Read the `neighborhood_coordinates.csv` file from the `Resources` folder into the notebook, and create a DataFrame named `neighborhood_locations_df`. Be sure to set the `index_col` of the DataFrame as “Neighborhood”.

# %%
# Load neighborhoods coordinates data
neighborhood_locations_df = pd.read_csv(data_1)

#set "index_col" as neighborhood
neighborhood_locations_df.set_index("Neighborhood",inplace= True)

# Review the DataFrame
neighborhood_locations_df
# Out:
#                           Lat         Lon
# Neighborhood
# Alamo Square        37.791012 -122.402100
# Anza Vista          37.779598 -122.443451
# Bayview             37.734670 -122.401060
# Bayview Heights     37.728740 -122.410980
# Bernal Heights      37.728630 -122.443050
# ...                       ...         ...
# West Portal         37.740260 -122.463880
# Western Addition    37.792980 -122.435790
# Westwood Highlands  37.734700 -122.456854
# Westwood Park       37.734150 -122.457000
# Yerba Buena         37.792980 -122.396360
#
# [73 rows x 2 columns]

# %% [markdown]
# ### Step 2: Using the original `sfo_data_df` Dataframe, create a DataFrame named `all_neighborhood_info_df` that groups the data by neighborhood. Aggregate the results by the `mean` of the group.

# %%
# Calculate the mean values for each neighborhood
all_neighborhood_info = sfo_data_df.groupby('Neighborhood').mean()

# Drop "year" column 
all_neighborhood_info_df=all_neighborhood_info.drop(columns=['year'])

# Review the resulting DataFrame
all_neighborhood_info_df
# Out:
#                     sale_price_sqr_foot  housing_units   gross_rent
# Neighborhood
# Alamo Square                 366.020712      378401.00  2817.285714
# Anza Vista                   373.382198      379050.00  3031.833333
# Bayview                      204.588623      376454.00  2318.400000
# Bayview Heights              590.792839      382295.00  3739.000000
# Bernal Heights               576.746488      379374.50  3080.333333
# ...                                 ...            ...          ...
# West Portal                  498.488485      376940.75  2515.500000
# Western Addition             307.562201      377427.50  2555.166667
# Westwood Highlands           533.703935      376454.00  2250.500000
# Westwood Park                687.087575      382295.00  3959.000000
# Yerba Buena                  576.709848      377427.50  2555.166667
#
# [73 rows x 3 columns]

# %% [markdown]
# ### Step 3: Review the two code cells that concatenate the `neighborhood_locations_df` DataFrame with the `all_neighborhood_info_df` DataFrame.

# %%
# Using the Pandas `concat` function, join the neighborhood_locations_df and the all_neighborhood_info_df DataFrame
# The axis of the concatenation is "columns".
# The concat function will automatially combine columns with identical information, while keeping the additional columns.
all_neighborhoods_df = pd.concat(
    [neighborhood_locations_df, all_neighborhood_info_df], 
    axis="columns",
    sort=False
)

# Review the resulting DataFrame
display(all_neighborhoods_df.head())
display(all_neighborhoods_df.tail())
# Out:
#                        Lat         Lon  sale_price_sqr_foot  housing_units  \
# Neighborhood
# Alamo Square     37.791012 -122.402100           366.020712       378401.0
# Anza Vista       37.779598 -122.443451           373.382198       379050.0
# Bayview          37.734670 -122.401060           204.588623       376454.0
# Bayview Heights  37.728740 -122.410980           590.792839       382295.0
# Bernal Heights   37.728630 -122.443050                  NaN            NaN
#
#                   gross_rent
# Neighborhood
# Alamo Square     2817.285714
# Anza Vista       3031.833333
# Bayview          2318.400000
# Bayview Heights  3739.000000
# Bernal Heights           NaN
#                       Lat        Lon  sale_price_sqr_foot  housing_units  \
# Neighborhood
# Yerba Buena      37.79298 -122.39636           576.709848       377427.5
# Bernal Heights        NaN        NaN           576.746488       379374.5
# ...

# %%
# Call the dropna function to remove any neighborhoods that do not have data
all_neighborhoods = all_neighborhoods_df.dropna()


# Review the resulting DataFrame
display(all_neighborhoods.head())
display(all_neighborhoods.tail())
# Out:
#                         Lat         Lon  sale_price_sqr_foot  housing_units  \
# Neighborhood
# Alamo Square      37.791012 -122.402100           366.020712       378401.0
# Anza Vista        37.779598 -122.443451           373.382198       379050.0
# Bayview           37.734670 -122.401060           204.588623       376454.0
# Bayview Heights   37.728740 -122.410980           590.792839       382295.0
# Buena Vista Park  37.768160 -122.439330           452.680591       378076.5
#
#                    gross_rent
# Neighborhood
# Alamo Square      2817.285714
# Anza Vista        3031.833333
# Bayview           2318.400000
# Bayview Heights   3739.000000
# Buena Vista Park  2698.833333
#                          Lat         Lon  sale_price_sqr_foot  housing_units  \
# Neighborhood
# West Portal         37.74026 -122.463880           498.488485      376940.75
# Western Addition    37.79298 -122.435790           307.562201      377427.50
# ...

# %% [markdown]
# ### Step 4: Using hvPlot with GeoViews enabled, create a `points` plot for the `all_neighborhoods_df` DataFrame. Be sure to do the following:

# %%
# Create a plot to analyze neighborhood info
all_neighborhoods.hvplot.points(
    'Lon', 
    'Lat', 
    ylabel='Latitude',
    xlabel='Longitude',
    label= 'San Francisco Housing Price by Neighborhood',
    geo=True, 
    size='sale_price_sqr_foot',
    color='gross_rent',
    tiles='OSM',
    frame_width=700,
    frame_height=500,
    hover_cols=["Neighborhood"],
)
# Out:
# :Overlay
#    .Tiles.I                                            :Tiles   [x,y]
#    .Points.San_Francisco_Housing_Price_by_Neighborhood :Points   [Lon,Lat]   (gross_rent,sale_price_sqr_foot,Neighborhood)

# %% [markdown]
# **Question:** Which neighborhood has the highest gross rent, and which has the highest sale price per square foot?
#
# **Answer:** The neighborhood with the highest gross rent is Westwood Highlands and the neighborhood with the highest sale price per square foot is Union Square District.

# %% [markdown]
# -----

# %% [markdown]
# ## Compose Your Data Story
#
# Based on the visualizations that you have created, compose a data story that synthesizes your analysis by answering the following questions:

# %% [markdown]
# **Question:**  How does the trend in rental income growth compare to the trend in sales prices? Does this same trend hold true for all the neighborhoods across San Francisco?
#
# **Answer:** There seem to be a similarity in the rental income growth across San Francisco. From the year 2010-2016, all neighborhoods have an inclined slope plotted which translates to an increase in price. On the other hand, the sales prices are different across San Francisco.

# %% [markdown]
# **Question:** What insights can you share with your company about the potential one-click, buy-and-rent strategy that they're pursuing? Do neighborhoods exist that you would suggest for investment, and why?
#
# **Answer:** I suggest my company invest in neighborhoods with low sales prices and high gross income, i.e., Alamos Square, Anza Vista, and stay away from neighborhoods where there is an increase in sale price like Bueno Vista Park. The reason is so they maximize profit.
